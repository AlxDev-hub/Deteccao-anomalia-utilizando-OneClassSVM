# %% [markdown]
# # Aplicação de detecção de anomalia utilizando One Class SVM
#
# O Dataset do experimento é dividido da seguinte maneira
#
# *   660 pontos de inliers
# *   2310 pontos de outliers

# %%
#Bibliotecas utilizadas
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import svm

# %%
#Carregar dataset - X_train
dataset = pd.read_excel("pzt2.xlsx", header=None)

display(dataset)
# Out:
#          0        1        2        3        4        5        6        7     \
# 0     30000.0  162.179  162.080  162.019  162.019  162.019  162.069  162.069
# 1     30010.0  164.697  164.647  164.697  164.537  164.537  164.588  164.537
# 2     30020.0  167.906  167.906  167.906  167.957  167.906  167.957  167.906
# 3     30030.0  171.637  171.583  171.583  171.637  171.583  171.637  171.637
# 4     30040.0  174.364  174.364  174.364  174.364  174.141  174.197  174.141
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 3995  69960.0  662.970  662.970  663.175  663.997  664.409  663.586  663.586
# 3996  69970.0  664.822  665.028  665.235  666.269  666.477  665.855  665.855
# 3997  69980.0  658.891  659.094  659.906  660.721  661.332  660.721  660.517
# 3998  69990.0  652.867  653.066  653.464  654.463  654.863  654.263  654.263
# 3999  70000.0  652.270  652.270  652.668  653.664  654.063  653.265  653.265
#
# ...

# %%
#Tratamento do dataset - Transpor dados
data = dataset.T

display(data)
# Out:
#            0          1          2          3          4          5     \
# 0     30000.000  30010.000  30020.000  30030.000  30040.000  30050.000
# 1       162.179    164.697    167.906    171.637    174.364    172.654
# 2       162.080    164.647    167.906    171.583    174.364    172.712
# 3       162.019    164.697    167.906    171.583    174.364    172.712
# 4       162.019    164.537    167.957    171.637    174.364    172.711
# ...         ...        ...        ...        ...        ...        ...
# 2966    186.265    188.648    191.684    195.185    200.095    207.909
# 2967    186.321    188.806    191.684    195.285    200.254    208.136
# 2968    186.265    188.806    191.684    195.285    200.095    208.071
# 2969    186.051    188.591    191.467    195.126    200.033    207.909
# 2970    186.016    188.389    191.367    194.749    199.714    207.522
#
#            6          7          8          9     ...       3990       3991  \
# ...

# %%
#Tratamento do dataset - Remover linha da frequencia
new_data = data.drop([0], axis=0)

display(new_data)
# Out:
#          0        1        2        3        4        5        6        7     \
# 1     162.179  164.697  167.906  171.637  174.364  172.654  163.434  156.894
# 2     162.080  164.647  167.906  171.583  174.364  172.712  163.434  156.894
# 3     162.019  164.697  167.906  171.583  174.364  172.712  163.380  156.894
# 4     162.019  164.537  167.957  171.637  174.364  172.711  163.487  156.944
# 5     162.019  164.537  167.906  171.583  174.141  172.712  163.434  156.944
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 2966  186.265  188.648  191.684  195.185  200.095  207.909  219.236  217.125
# 2967  186.321  188.806  191.684  195.285  200.254  208.136  219.166  217.437
# 2968  186.265  188.806  191.684  195.285  200.095  208.071  219.236  217.229
# 2969  186.051  188.591  191.467  195.126  200.033  207.909  219.096  217.333
# 2970  186.016  188.389  191.367  194.749  199.714  207.522  218.859  217.437
#
# ...

# %%
#Aplicando PCA no dataset
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(new_data)
principalDf = pd.DataFrame(data= principalComponents)

display(principalDf)
# Out:
#                 0            1
# 0    -3757.321769 -2506.468672
# 1    -3764.218235 -2507.132629
# 2    -3758.148909 -2506.991646
# 3    -3757.018323 -2507.569697
# 4    -3753.454942 -2507.360926
# ...           ...          ...
# 2965  4498.793827 -3110.722421
# 2966  4498.274936 -3109.967169
# 2967  4501.164031 -3107.487505
# 2968  4521.506774 -3093.920713
# 2969  4548.381360 -3068.093423
#
# [2970 rows x 2 columns]

# %%
#Definindo dados de treinamento
X_train = principalDf.iloc[0: 660]

display(X_train)
# Out:
#                0            1
# 0   -3757.321769 -2506.468672
# 1   -3764.218235 -2507.132629
# 2   -3758.148909 -2506.991646
# 3   -3757.018323 -2507.569697
# 4   -3753.454942 -2507.360926
# ..           ...          ...
# 655  5340.674138 -3426.271245
# 656  5335.562659 -3425.819520
# 657  5330.406593 -3425.528513
# 658  5348.506169 -3407.681393
# 659  5376.954016 -3361.066586
#
# [660 rows x 2 columns]

# %%
#Definindo dados de teste
X_test = principalDf.iloc[660: 2970]

display(X_test)
# Out:
#                 0            1
# 660  -3735.333706 -2368.615620
# 661  -3744.728973 -2385.313554
# 662  -3748.265277 -2397.217455
# 663  -3748.551349 -2406.915688
# 664  -3750.666364 -2413.813543
# ...           ...          ...
# 2965  4498.793827 -3110.722421
# 2966  4498.274936 -3109.967169
# 2967  4501.164031 -3107.487505
# 2968  4521.506774 -3093.920713
# 2969  4548.381360 -3068.093423
#
# [2310 rows x 2 columns]

# %%
#Aplicando SVM
clf = svm.OneClassSVM(gamma=0.1)
clf.fit(X_train)
# Out:
# OneClassSVM(gamma=0.1)

# %%
#Predição de outliers
y_pred = clf.predict(X_test)  # 1: inlier, -1: outlier
n_error_outlier = y_pred[y_pred == -1].size

print("Outliers identificados: ", n_error_outlier)
# Out:
# Outliers identificados:  2310
